# %% [markdown]
# # Process chain

# %% [markdown]
# ## Importing modules

# %%
from process import process
from utils.plot import plot_lines, define_plot_data
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Variable definition

# %%
input_fpath = 'files/inp.xlsx'
output_fpath = 'files/out.xlsx'
column_mapping = {'Time [s]': 'time', 'Velocity [m/s]': 'velocity'}

# %% [markdown]
# ## Processing chain model

# %%
dsp = process.register()
# Click on the graph to see the model.
dsp.plot(view=False)
# Out:
# SiteMap([(Processing Model, SiteMap([(compute_outputs, SiteMap())]))])

# %% [markdown]
# # Model Execution

# %%
sol = dsp(dict(input_fpath=input_fpath, output_fpath=output_fpath, column_mapping=column_mapping))
sol['outputs']
# Out:
# Solution([('time', array([0, 1, 2, 3, 4])),
#           ('velocity', array([0, 2, 3, 1, 0])),
#           ('acceleration', array([ 2. ,  1.5, -0.5, -1.5, -1. ])),
#           ('distance', array([0. , 1. , 3.5, 5.5, 6. ]))])

# %%
# Click on the graph to see the model results.
sol.plot(view=False)
# Out:
# SiteMap([(Processing Model, SiteMap([(compute_outputs, SiteMap())]))])

# %% [markdown]
# # Plot Results

# %%
plot_lines(define_plot_data(sol['outputs'], 'time',  'distance', 'velocity', 'acceleration'))
# Out:
# <div id="93946cbb-045e-49f1-9b3e-b5ecdccca783" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("93946cbb-045e-49f1-9b3e-b5ecdccca783", [{"mode": "lines", "name": "distance", "x": [0, 1, 2, 3, 4], "y": [0.0, 1.0, 3.5, 5.5, 6.0], "type": "scatter", "uid": "171ae318-130a-407d-a2c0-e0c21b04890d"}, {"mode": "lines", "name": "velocity", "x": [0, 1, 2, 3, 4], "y": [0, 2, 3, 1, 0], "type": "scatter", "uid": "2fc6522b-f248-49c5-ab2c-93273825751d"}, {"mode": "lines", "name": "acceleration", "x": [0, 1, 2, 3, 4], "y": [2.0, 1.5, -0.5, -1.5, -1.0], "type": "scatter", "uid": "901c6da9-a13e-4f76-9213-c79c4100304d"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("93946cbb-045e-49f1-9b3e-b5ecdccca783"));});</script>
