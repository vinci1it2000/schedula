# %% [markdown]
# # Length converter

# %% [markdown]
# ## Importing modules

# %%
import schedula as sh
from converter import converter, metric, imperial

# %% [markdown]
# ## Metric model

# %%
# Click on the graph to see the model.
metric.register().plot(view=False, engine='neato', body={'style': 'filled'})
# Out:
# SiteMap([(Metric, SiteMap())])

# %% [markdown]
# ## Imperial model

# %%
# Click on the graph to see the model.
imperial.register().plot(view=False, engine='neato', body={'style': 'filled'})
# Out:
# SiteMap([(Imperial, SiteMap())])

# %% [markdown]
# ## Coverter model

# %%
dsp = converter.register()
# Click on the graph to see the model.
dsp.plot(view=False, engine='neato', body={'style': 'filled'})
# Out:
# SiteMap([(LengthConverter, SiteMap())])

# %% [markdown]
# # Model Execution

# %%
sol = dsp.dispatch(inputs={'cm': 2.5})
sol
# Out:
# Solution([('cm', 2.5),
#           ('in', 0.984251968503937),
#           ('mm', 25.0),
#           ('km', 2.5e-05),
#           ('th', 984.2519685039371),
#           ('lea', 5.17809326864445e-06),
#           ('m', 0.025),
#           ('dm', 0.25),
#           ('mi', 1.553427980593335e-05),
#           ('fur', 0.0001242742384474668),
#           ('ch', 0.001242742384474668),
#           ('yd', 0.027340332458442695),
#           ('ft', 0.08202099737532809)])

# %%
# Click on the graph to see the model.
sol.plot(view=False, body={'style': 'filled'})
# Out:
# SiteMap([(LengthConverter, SiteMap())])
